# %%
import numpy as np 
import pandas as pd 
import pickle

# %%
frozen_consensus_master_sheet_nanatmaj_with_hpo  = pd.read_excel(r'D:\learning\HPOA dataset\GitHub uploads\Final_concnecous\Version_110923\proportion_counting\Frozen_consensus_MasterSheet_HPOtermsWithVPK_V_110923xlsx.xlsx')
frozen_consensus_master_sheet_nanatmaj_with_hpo
# Out:
#          HP_Terms                           Description  V  P  K NV NP NK
# 0      HP:0002013                              Vomiting  V  0  0  0  0  0
# 1      HP:0002153                          Hyperkalemia  0  P  0  0  0  0
# 2      HP:0000848     Increased circulating renin level  0  P  0  0  0  0
# 3      HP:0001508                     Failure to thrive  V  0  0  0  0  0
# 4      HP:0001944                           Dehydration  0  P  0  0  0  0
# ...           ...                                   ... .. .. .. .. .. ..
# 10605  HP:0032410  Bilateral generalized polymicrogyria  V  0  0  0  0  0
# 10606  HP:0009067   Progressive spinal muscular atrophy  V  0  0  0  0  0
# 10607  HP:0032026                            Anetoderma  V  0  0  0  0  0
# 10608  HP:0030817                          Beaked nails  V  0  0  0  0  0
# 10609  HP:0031009                                Ainhum  V  0  0  0  0  0
#
# [10610 rows x 8 columns]

# %%
def pickle_load(file_path):
    with open(file_path, 'rb') as handle:
        b = pickle.load(handle)
    return b
path_disease_hpo_dict = 'D:\learning\HPOA dataset\GitHub uploads\Final_concnecous\data_retrival\disease_hpo_dict_V_110923.pickle'
path_disease_name_dict = 'D:\learning\HPOA dataset\GitHub uploads\Final_concnecous\data_retrival\disease_name_dict_V_110923.pickle'
path_hpid_descriptions_dict = 'D:\learning\HPOA dataset\GitHub uploads\Final_concnecous\data_retrival\hpid_descriptions_dict_V_110923.pickle'
path_hpid_vpk_label_dict = 'D:\learning\HPOA dataset\GitHub uploads\Final_concnecous\data_retrival\hpid_vpk_label_dict_V_110923.pickle'
path_hpo_disease_dict = 'D:\learning\HPOA dataset\GitHub uploads\Final_concnecous\data_retrival\hpo_disease_dict_V_110923.pickle'
path_disease_vpk_count_dict = 'D:\learning\HPOA dataset\GitHub uploads\Final_concnecous\data_retrival\disease_vpk_count_dict_V_110923.pickle'
# loading dicts #tanay path
disease_hpo_dict = pickle_load(path_disease_hpo_dict)
disease_name_dict =  pickle_load(path_disease_name_dict)
hpid_descriptions_dict =  pickle_load(path_hpid_descriptions_dict)
hpid_vpk_label_dict =  pickle_load(path_hpid_vpk_label_dict)
hpo_disease_dict =  pickle_load(path_hpo_disease_dict)
disease_vpk_count_dict = pickle_load(path_disease_vpk_count_dict)

# %%
frozen_concensus_disease_mastersheet_for_disease_df = pd.read_excel('D:\learning\HPOA dataset\GitHub uploads\Final_concnecous\Frozen_consensus_MasterSheet_V.1.0_HPODiseaseWithVPK.xlsx')
disease_df = frozen_concensus_disease_mastersheet_for_disease_df[['Disease_ID']]
disease_list = disease_df.values.tolist()

# %%
disease_list = [i for row in disease_list for i in row]
# disease_list
# Out:
# ['DECIPHER:1',
#  'DECIPHER:14',
#  'DECIPHER:15',
#  'DECIPHER:16',
#  'DECIPHER:17',
#  'DECIPHER:18',
#  'DECIPHER:19',
#  'DECIPHER:2',
#  'DECIPHER:20',
#  'DECIPHER:21',
#  'DECIPHER:29',
#  'DECIPHER:3',
#  'DECIPHER:31',
#  'DECIPHER:32',
#  'DECIPHER:34',
#  'DECIPHER:35',
#  'DECIPHER:37',
#  'DECIPHER:38',
#  'DECIPHER:39',
#  'DECIPHER:4',
#  'DECIPHER:42',
#  'DECIPHER:43',
#  'DECIPHER:44',
#  'DECIPHER:45',
#  'DECIPHER:46',
#  'DECIPHER:47',
#  'DECIPHER:48',
#  'DECIPHER:51',
#  'DECIPHER:52',
#  'DECIPHER:53',
#  'DECIPHER:54',
#  'DECIPHER:57',
#  'DECIPHER:58',
#  'DECIPHER:59',
#  'DECIPHER:62',
#  'DECIPHER:65',
#  'DECIPHER:66',
#  'DECIPHER:67',
#  'DECIPHER:68',
#  'DECIPHER:70',
#  'DECIPHER:72',
#  'DECIPHER:74',
#  'DECIPHER:76',
#  'DECIPHER:8',
#  'DECIPHER:81',
#  'DECIPHER:85',
#  'DECIPHER:92',
#  'OMIM:100050',
#  'OMIM:100070',
#  'OMIM:100100',
#  'OMIM:100200',
#  'OMIM:100300',
#  'OMIM:100600',
#  'OMIM:100700',
#  'OMIM:100800',
#  'OMIM:100820',
#  'OMIM:101000',
#  'OMIM:101200',
#  'OMIM:101400',
#  'OMIM:101600',
#  'OMIM:101800',
#  'OMIM:101805',
#  'OMIM:101840',
#  'OMIM:101850',
#  'OMIM:101900',
#  'OMIM:102000',
#  'OMIM:102100',
#  'OMIM:102150',
#  'OMIM:102200',
#  'OMIM:102300',
#  'OMIM:102350',
#  'OMIM:102370',
#  'OMIM:102400',
#  'OMIM:102500',
#  'OMIM:102510',
#  'OMIM:102520',
#  'OMIM:102530',
#  'OMIM:102650',
#  'OMIM:102660',
#  'OMIM:102700',
#  'OMIM:102800',
#  'OMIM:102900',
#  'OMIM:103050',
#  'OMIM:103100',
#  'OMIM:103200',
#  'OMIM:103230',
#  'OMIM:103285',
#  'OMIM:103300',
#  'OMIM:103420',
#  'OMIM:103500',
#  'OMIM:103580',
#  'OMIM:103780',
#  'OMIM:103900',
#  'OMIM:103920',
#  'OMIM:104000',
#  'OMIM:104100',
#  'OMIM:104110',
#  'OMIM:104130',
#  'OMIM:104200',
#  'OMIM:104290',
#  'OMIM:104300',
#  'OMIM:104310',
#  'OMIM:104350',
#  'OMIM:104400',
#  'OMIM:104500',
#  'OMIM:104510',
#  'OMIM:104530',
#  'OMIM:104570',
#  'OMIM:104600',
#  'OMIM:105120',
#  'OMIM:105150',
#  'OMIM:105200',
#  'OMIM:105210',
#  'OMIM:105250',
#  'OMIM:105300',
#  'OMIM:105400',
#  'OMIM:105500',
#  'OMIM:105550',
#  'OMIM:105563',
#  'OMIM:105565',
#  'OMIM:105580',
#  'OMIM:105600',
#  'OMIM:105650',
#  'OMIM:105800',
#  'OMIM:105805',
#  'OMIM:105830',
#  'OMIM:105835',
#  'OMIM:106050',
#  'OMIM:106070',
#  'OMIM:106100',
#  'OMIM:106190',
#  'OMIM:106210',
#  'OMIM:106220',
#  'OMIM:106230',
#  'OMIM:106250',
#  'OMIM:106260',
#  'OMIM:106280',
#  'OMIM:106300',
#  'OMIM:106400',
#  'OMIM:106500',
#  'OMIM:106600',
#  'OMIM:106700',
#  'OMIM:106750',
#  'OMIM:106900',
#  'OMIM:106990',
#  'OMIM:106995',
#  'OMIM:107000',
#  'OMIM:107100',
#  'OMIM:107200',
#  'OMIM:107250',
#  'OMIM:107320',
#  'OMIM:107480',
#  'OMIM:107500',
#  'OMIM:107550',
#  'OMIM:107600',
#  'OMIM:107640',
#  'OMIM:107650',
#  'OMIM:107700',
#  'OMIM:107900',
#  'OMIM:107970',
#  'OMIM:108000',
#  'OMIM:108010',
#  'OMIM:108050',
#  'OMIM:108120',
#  'OMIM:108145',
#  'OMIM:108200',
#  'OMIM:108300',
#  'OMIM:108420',
#  'OMIM:108450',
#  'OMIM:108500',
#  'OMIM:108600',
#  'OMIM:108650',
#  'OMIM:108700',
#  'OMIM:108720',
#  'OMIM:108721',
#  'OMIM:108725',
#  'OMIM:108760',
#  'OMIM:108770',
#  'OMIM:108800',
#  'OMIM:108900',
#  'OMIM:108950',
#  'OMIM:108985',
#  'OMIM:109000',
#  'OMIM:109050',
#  'OMIM:109100',
#  'OMIM:109120',
#  'OMIM:109130',
#  'OMIM:109150',
#  'OMIM:109200',
#  'OMIM:109270',
#  'OMIM:109350',
#  'OMIM:109400',
#  'OMIM:109500',
#  'OMIM:109543',
#  'OMIM:109650',
#  'OMIM:109720',
#  'OMIM:109730',
#  'OMIM:109740',
#  'OMIM:109800',
#  'OMIM:109820',
#  'OMIM:109900',
#  'OMIM:110000',
#  'OMIM:110050',
#  'OMIM:110100',
#  'OMIM:110150',
#  'OMIM:112200',
#  'OMIM:112240',
#  'OMIM:112250',
#  'OMIM:112270',
#  'OMIM:112300',
#  'OMIM:112310',
#  'OMIM:112350',
#  'OMIM:112370',
#  'OMIM:112410',
#  'OMIM:112440',
#  'OMIM:112450',
#  'OMIM:112500',
#  'OMIM:112600',
#  'OMIM:112700',
#  'OMIM:112800',
#  'OMIM:112910',
#  'OMIM:113000',
#  'OMIM:113100',
#  'OMIM:113200',
#  'OMIM:113300',
#  'OMIM:113301',
#  'OMIM:113310',
#  'OMIM:113400',
#  'OMIM:113450',
#  'OMIM:113475',
#  'OMIM:113477',
#  'OMIM:113500',
#  'OMIM:113600',
#  'OMIM:113610',
#  'OMIM:113620',
#  'OMIM:113650',
#  'OMIM:113670',
#  'OMIM:113700',
#  'OMIM:113750',
#  'OMIM:113800',
#  'OMIM:113900',
#  'OMIM:113950',
#  'OMIM:113970',
#  'OMIM:114000',
#  'OMIM:114030',
#  'OMIM:114065',
#  'OMIM:114100',
#  'OMIM:114140',
#  'OMIM:114150',
#  'OMIM:114200',
#  'OMIM:114290',
#  'OMIM:114300',
#  'OMIM:114450',
#  'OMIM:114480',
#  'OMIM:114500',
#  'OMIM:114550',
#  'OMIM:114580',
#  'OMIM:114600',
#  'OMIM:114620',
#  'OMIM:114650',
#  'OMIM:114700',
#  'OMIM:114900',
#  'OMIM:115000',
#  'OMIM:115080',
#  'OMIM:115150',
#  'OMIM:115195',
#  'OMIM:115196',
#  'OMIM:115197',
#  'OMIM:115200',
#  'OMIM:115210',
#  'OMIM:115250',
#  'OMIM:115300',
#  'OMIM:115310',
#  'OMIM:115400',
#  'OMIM:115430',
#  'OMIM:115470',
#  'OMIM:115650',
#  'OMIM:115660',
#  'OMIM:115665',
#  'OMIM:115700',
#  'OMIM:115800',
#  'OMIM:115900',
#  'OMIM:116100',
#  'OMIM:116200',
#  'OMIM:116300',
#  'OMIM:116400',
#  'OMIM:116600',
#  'OMIM:116700',
#  'OMIM:116800',
#  'OMIM:116860',
#  'OMIM:116870',
#  'OMIM:116920',
#  'OMIM:117000',
#  'OMIM:117100',
#  'OMIM:117210',
#  'OMIM:117300',
#  'OMIM:117360',
#  'OMIM:117550',
#  'OMIM:117650',
#  'OMIM:117850',
#  'OMIM:117900',
#  'OMIM:118000',
#  'OMIM:118005',
#  'OMIM:118100',
#  'OMIM:118200',
#  'OMIM:118210',
#  'OMIM:118220',
#  'OMIM:118300',
#  'OMIM:118301',
#  'OMIM:118350',
#  'OMIM:118400',
#  'OMIM:118420',
#  'OMIM:118450',
#  'OMIM:118600',
#  'OMIM:118610',
#  'OMIM:118650',
#  'OMIM:118651',
#  'OMIM:118700',
#  'OMIM:118750',
#  'OMIM:118800',
#  'OMIM:118830',
#  'OMIM:118865',
#  'OMIM:118900',
#  'OMIM:119100',
#  'OMIM:119300',
#  'OMIM:119500',
#  'OMIM:119530',
#  'OMIM:119540',
#  'OMIM:119550',
#  'OMIM:119570',
#  'OMIM:119580',
#  'OMIM:119600',
#  'OMIM:119650',
#  'OMIM:119800',
#  'OMIM:119900',
#  'OMIM:119915',
#  'OMIM:120000',
#  'OMIM:120040',
#  'OMIM:120050',
#  'OMIM:120100',
#  'OMIM:120200',
#  'OMIM:120300',
#  'OMIM:120330',
#  'OMIM:120400',
#  'OMIM:120430',
#  'OMIM:120433',
#  'OMIM:120435',
#  'OMIM:120440',
#  'OMIM:120450',
#  'OMIM:120500',
#  'OMIM:120502',
#  'OMIM:120790',
#  'OMIM:120970',
#  'OMIM:121050',
#  'OMIM:121070',
#  'OMIM:121200',
#  'OMIM:121201',
#  'OMIM:121210',
#  'OMIM:121270',
#  'OMIM:121300',
#  'OMIM:121350',
#  'OMIM:121390',
#  'OMIM:121400',
#  'OMIM:121800',
#  'OMIM:121820',
#  'OMIM:121850',
#  'OMIM:121900',
#  'OMIM:122000',
#  'OMIM:122100',
#  'OMIM:122200',
#  'OMIM:122400',
#  'OMIM:122430',
#  'OMIM:122440',
#  'OMIM:122450',
#  'OMIM:122455',
#  'OMIM:122460',
#  'OMIM:122470',
#  'OMIM:122580',
#  'OMIM:122600',
#  'OMIM:122700',
#  'OMIM:122750',
#  'OMIM:122780',
#  'OMIM:122850',
#  'OMIM:122860',
#  'OMIM:122880',
#  'OMIM:122900',
#  'OMIM:123000',
#  'OMIM:123050',
#  'OMIM:123100',
#  'OMIM:123150',
#  'OMIM:123155',
#  'OMIM:123320',
#  'OMIM:123400',
#  'OMIM:123450',
#  'OMIM:123500',
#  'OMIM:123540',
#  'OMIM:123550',
#  'OMIM:123557',
#  'OMIM:123560',
#  'OMIM:123570',
#  'OMIM:123700',
#  'OMIM:123790',
#  'OMIM:123880',
#  'OMIM:124000',
#  'OMIM:124100',
#  'OMIM:124200',
#  'OMIM:124300',
#  'OMIM:124480',
#  'OMIM:124500',
#  'OMIM:124700',
#  'OMIM:124900',
#  'OMIM:124950',
#  'OMIM:125000',
#  'OMIM:125050',
#  'OMIM:125230',
#  'OMIM:125250',
#  'OMIM:125310',
#  'OMIM:125320',
#  'OMIM:125350',
#  'OMIM:125370',
#  'OMIM:125400',
#  'OMIM:125420',
#  'OMIM:125440',
#  'OMIM:125460',
#  'OMIM:125480',
#  'OMIM:125490',
#  'OMIM:125500',
#  'OMIM:125520',
#  'OMIM:125530',
#  'OMIM:125540',
#  'OMIM:125595',
#  'OMIM:125600',
#  'OMIM:125630',
#  'OMIM:125635',
#  'OMIM:125640',
#  'OMIM:125700',
#  'OMIM:125800',
#  'OMIM:125850',
#  'OMIM:125851',
#  'OMIM:125852',
#  'OMIM:125853',
#  'OMIM:125900',
#  'OMIM:126050',
#  'OMIM:126070',
#  'OMIM:126180',
#  'OMIM:126190',
#  'OMIM:126200',
#  'OMIM:126250',
#  'OMIM:126300',
#  'OMIM:126320',
#  'OMIM:126500',
#  'OMIM:126550',
#  'OMIM:126600',
#  'OMIM:126700',
#  'OMIM:126800',
#  'OMIM:126840',
#  'OMIM:126850',
#  'OMIM:126900',
#  'OMIM:126950',
#  'OMIM:127000',
#  'OMIM:127100',
#  'OMIM:127200',
#  'OMIM:127300',
#  'OMIM:127350',
#  'OMIM:127400',
#  'OMIM:127500',
#  'OMIM:127550',
#  'OMIM:127600',
#  'OMIM:127700',
#  'OMIM:127750',
#  'OMIM:127800',
#  'OMIM:127820',
#  'OMIM:128000',
#  'OMIM:128100',
#  'OMIM:128101',
#  'OMIM:128200',
#  'OMIM:128230',
#  'OMIM:128235',
#  'OMIM:128290',
#  'OMIM:128300',
#  'OMIM:128500',
#  'OMIM:128600',
#  'OMIM:128700',
#  'OMIM:128710',
#  'OMIM:128800',
#  'OMIM:128980',
#  'OMIM:129000',
#  'OMIM:129150',
#  'OMIM:129200',
#  'OMIM:129400',
#  'OMIM:129490',
#  'OMIM:129500',
#  'OMIM:129550',
#  'OMIM:129600',
#  'OMIM:129750',
#  'OMIM:129810',
#  'OMIM:129830',
#  'OMIM:129840',
#  'OMIM:129850',
#  'OMIM:129900',
#  'OMIM:130000',
#  'OMIM:130010',
#  'OMIM:130020',
#  'OMIM:130050',
#  'OMIM:130060',
#  'OMIM:130070',
#  'OMIM:130080',
#  'OMIM:130100',
#  'OMIM:130200',
#  'OMIM:130300',
#  'OMIM:130600',
#  'OMIM:130650',
#  'OMIM:130700',
#  'OMIM:130710',
#  'OMIM:130720',
#  'OMIM:130900',
#  'OMIM:130950',
#  'OMIM:131100',
#  'OMIM:131200',
#  'OMIM:131300',
#  'OMIM:131400',
#  'OMIM:131430',
#  'OMIM:131440',
#  'OMIM:131705',
#  'OMIM:131750',
#  'OMIM:131760',
#  'OMIM:131800',
#  'OMIM:131850',
#  'OMIM:131880',
#  'OMIM:131900',
#  'OMIM:131950',
#  'OMIM:131960',
#  'OMIM:132000',
#  'OMIM:132090',
#  'OMIM:132100',
#  'OMIM:132300',
#  'OMIM:132400',
#  'OMIM:132450',
#  'OMIM:132500',
#  'OMIM:132600',
#  'OMIM:132700',
#  'OMIM:132800',
#  'OMIM:132900',
#  'OMIM:132990',
#  'OMIM:133000',
#  'OMIM:133020',
#  'OMIM:133100',
#  'OMIM:133180',
#  'OMIM:133190',
#  'OMIM:133200',
#  'OMIM:133239',
#  'OMIM:133240',
#  'OMIM:133500',
#  'OMIM:133540',
#  'OMIM:133600',
#  'OMIM:133690',
#  'OMIM:133700',
#  'OMIM:133701',
#  'OMIM:133705',
#  'OMIM:133750',
#  'OMIM:133780',
#  'OMIM:133900',
#  'OMIM:134200',
#  'OMIM:134300',
#  'OMIM:134400',
#  'OMIM:134430',
#  'OMIM:134500',
#  'OMIM:134510',
#  'OMIM:134520',
#  'OMIM:134540',
#  'OMIM:134600',
#  'OMIM:134610',
#  'OMIM:134750',
#  'OMIM:134780',
#  'OMIM:134900',
#  'OMIM:135100',
#  'OMIM:135150',
#  'OMIM:135290',
#  'OMIM:135300',
#  'OMIM:135400',
#  'OMIM:135500',
#  'OMIM:135550',
#  'OMIM:135580',
#  'OMIM:135700',
#  'OMIM:135750',
#  'OMIM:135800',
#  'OMIM:135900',
#  'OMIM:135950',
#  'OMIM:136000',
#  'OMIM:136120',
#  'OMIM:136140',
#  'OMIM:136300',
#  'OMIM:136400',
#  'OMIM:136480',
#  'OMIM:136500',
#  'OMIM:136520',
#  'OMIM:136550',
#  'OMIM:136570',
#  'OMIM:136580',
#  'OMIM:136600',
#  'OMIM:136630',
#  'OMIM:136680',
#  'OMIM:136760',
#  'OMIM:136800',
#  'OMIM:136880',
#  'OMIM:136900',
#  'OMIM:137040',
#  'OMIM:137050',
#  'OMIM:137100',
#  'OMIM:137200',
#  'OMIM:137210',
#  'OMIM:137215',
#  'OMIM:137245',
#  'OMIM:137270',
#  'OMIM:137280',
#  'OMIM:137360',
#  'OMIM:137370',
#  'OMIM:137440',
#  'OMIM:137500',
#  'OMIM:137550',
#  'OMIM:137560',
#  'OMIM:137575',
#  'OMIM:137580',
#  'OMIM:137600',
#  'OMIM:137700',
#  'OMIM:137750',
#  'OMIM:137760',
#  'OMIM:137763',
#  'OMIM:137800',
#  'OMIM:137900',
#  'OMIM:137920',
#  'OMIM:137940',
#  'OMIM:137950',
#  'OMIM:138000',
#  'OMIM:138070',
#  'OMIM:138500',
#  'OMIM:138770',
#  'OMIM:138790',
#  'OMIM:138800',
#  'OMIM:138930',
#  'OMIM:139000',
#  'OMIM:139090',
#  'OMIM:139210',
#  'OMIM:139300',
#  'OMIM:139393',
#  'OMIM:139600',
#  'OMIM:139630',
#  'OMIM:139650',
#  'OMIM:139750',
#  'OMIM:140000',
#  'OMIM:140300',
#  'OMIM:140350',
#  'OMIM:140400',
#  'OMIM:140450',
#  'OMIM:140500',
#  'OMIM:140600',
#  'OMIM:140700',
#  'OMIM:140850',
#  'OMIM:140900',
#  'OMIM:141000',
#  'OMIM:141200',
#  'OMIM:141300',
#  'OMIM:141350',
#  'OMIM:141400',
#  'OMIM:141405',
#  'OMIM:141500',
#  'OMIM:141749',
#  'OMIM:142000',
#  'OMIM:142309',
#  'OMIM:142330',
#  'OMIM:142340',
#  'OMIM:142350',
#  'OMIM:142400',
#  'OMIM:142623',
#  'OMIM:142625',
#  'OMIM:142630',
#  'OMIM:142669',
#  'OMIM:142680',
#  'OMIM:142690',
#  'OMIM:142700',
#  'OMIM:142900',
#  'OMIM:142945',
#  'OMIM:142946',
#  'OMIM:143000',
#  'OMIM:143050',
#  'OMIM:143095',
#  'OMIM:143100',
#  'OMIM:143200',
#  'OMIM:143400',
#  'OMIM:143465',
#  'OMIM:143470',
#  'OMIM:143500',
#  'OMIM:143850',
#  'OMIM:143860',
#  'OMIM:143870',
#  'OMIM:143880',
#  'OMIM:143890',
#  'OMIM:144010',
#  'OMIM:144050',
#  'OMIM:144100',
#  'OMIM:144110',
#  'OMIM:144150',
#  'OMIM:144200',
#  'OMIM:144250',
#  'OMIM:144300',
#  'OMIM:144600',
#  'OMIM:144650',
#  'OMIM:144700',
#  'OMIM:144750',
#  'OMIM:144755',
#  'OMIM:144800',
#  'OMIM:145000',
#  'OMIM:145001',
#  'OMIM:145100',
#  'OMIM:145200',
#  'OMIM:145250',
#  'OMIM:145260',
#  'OMIM:145290',
#  'OMIM:145295',
#  'OMIM:145300',
#  'OMIM:145350',
#  'OMIM:145420',
#  'OMIM:145500',
#  'OMIM:145590',
#  'OMIM:145600',
#  'OMIM:145650',
#  'OMIM:145680',
#  'OMIM:145700',
#  'OMIM:145701',
#  'OMIM:145750',
#  'OMIM:145800',
#  'OMIM:145900',
#  'OMIM:145980',
#  'OMIM:145981',
#  'OMIM:146000',
#  'OMIM:146110',
#  'OMIM:146160',
#  'OMIM:146200',
#  'OMIM:146255',
#  'OMIM:146300',
#  'OMIM:146350',
#  'OMIM:146390',
#  'OMIM:146450',
#  'OMIM:146500',
#  'OMIM:146510',
#  'OMIM:146520',
#  'OMIM:146550',
#  'OMIM:146590',
#  'OMIM:146600',
#  'OMIM:146700',
#  'OMIM:146720',
#  'OMIM:146750',
#  'OMIM:146800',
#  'OMIM:146830',
#  'OMIM:146850',
#  'OMIM:147050',
#  'OMIM:147060',
#  'OMIM:147250',
#  'OMIM:147251',
#  'OMIM:147330',
#  'OMIM:147350',
#  'OMIM:147400',
#  'OMIM:147421',
#  'OMIM:147430',
#  'OMIM:147480',
#  'OMIM:147530',
#  'OMIM:147540',
#  'OMIM:147610',
#  'OMIM:147630',
#  'OMIM:147710',
#  'OMIM:147750',
#  'OMIM:147770',
#  'OMIM:147791',
#  'OMIM:147800',
#  'OMIM:147820',
#  'OMIM:147891',
#  'OMIM:147892',
#  'OMIM:147900',
#  'OMIM:147920',
#  'OMIM:147950',
#  'OMIM:148000',
#  'OMIM:148050',
#  'OMIM:148100',
#  'OMIM:148190',
#  'OMIM:148200',
#  'OMIM:148210',
#  'OMIM:148300',
#  'OMIM:148350',
#  'OMIM:148360',
#  'OMIM:148370',
#  'OMIM:148500',
#  'OMIM:148520',
#  'OMIM:148600',
#  'OMIM:148700',
#  'OMIM:148730',
#  'OMIM:148800',
#  'OMIM:148820',
#  'OMIM:148840',
#  'OMIM:149000',
#  'OMIM:149100',
#  'OMIM:149200',
#  'OMIM:149300',
#  'OMIM:149400',
#  'OMIM:149500',
#  'OMIM:149600',
#  'OMIM:149700',
#  'OMIM:149730',
#  'OMIM:150170',
#  'OMIM:150230',
#  'OMIM:150250',
#  'OMIM:150260',
#  'OMIM:150270',
#  'OMIM:150280',
#  'OMIM:150300',
#  'OMIM:150360',
#  'OMIM:150400',
#  'OMIM:150500',
#  'OMIM:150550',
#  'OMIM:150600',
#  'OMIM:150699',
#  'OMIM:150700',
#  'OMIM:150800',
#  'OMIM:150900',
#  'OMIM:151000',
#  'OMIM:151001',
#  'OMIM:151050',
#  'OMIM:151100',
#  'OMIM:151200',
#  'OMIM:151210',
#  'OMIM:151380',
#  'OMIM:151400',
#  'OMIM:151430',
#  'OMIM:151500',
#  'OMIM:151600',
#  'OMIM:151610',
#  'OMIM:151620',
#  'OMIM:151623',
#  'OMIM:151630',
#  'OMIM:151640',
#  'OMIM:151660',
#  'OMIM:151700',
#  'OMIM:151800',
#  'OMIM:151900',
#  'OMIM:152420',
#  'OMIM:152550',
#  'OMIM:152700',
#  'OMIM:152800',
#  'OMIM:152900',
#  'OMIM:152950',
#  'OMIM:153100',
#  'OMIM:153200',
#  'OMIM:153300',
#  'OMIM:153400',
#  'OMIM:153470',
#  'OMIM:153480',
#  'OMIM:153550',
#  'OMIM:153600',
#  'OMIM:153630',
#  'OMIM:153640',
#  'OMIM:153670',
#  'OMIM:153700',
#  'OMIM:153800',
#  'OMIM:153840',
#  'OMIM:153870',
#  'OMIM:153880',
#  'OMIM:153890',
#  'OMIM:154020',
#  'OMIM:154230',
#  'OMIM:154275',
#  'OMIM:154276',
#  'OMIM:154300',
#  'OMIM:154400',
#  'OMIM:154500',
#  'OMIM:154570',
#  'OMIM:154600',
#  'OMIM:154700',
#  'OMIM:154750',
#  'OMIM:154780',
#  'OMIM:154800',
#  'OMIM:155000',
#  'OMIM:155050',
#  'OMIM:155100',
#  'OMIM:155140',
#  'OMIM:155145',
#  'OMIM:155200',
#  'OMIM:155240',
#  'OMIM:155255',
#  'OMIM:155310',
#  'OMIM:155350',
#  'OMIM:155500',
#  'OMIM:155600',
#  'OMIM:155601',
#  'OMIM:155700',
#  'OMIM:155720',
#  'OMIM:155755',
#  'OMIM:155900',
#  'OMIM:155950',
#  'OMIM:155980',
#  'OMIM:156000',
#  'OMIM:156190',
#  'OMIM:156200',
#  'OMIM:156220',
#  'OMIM:156230',
#  'OMIM:156232',
#  'OMIM:156240',
#  'OMIM:156250',
#  'OMIM:156310',
#  'OMIM:156400',
#  'OMIM:156500',
#  'OMIM:156510',
#  'OMIM:156520',
#  'OMIM:156530',
#  'OMIM:156550',
#  'OMIM:156580',
#  'OMIM:156600',
#  'OMIM:156610',
#  'OMIM:156700',
#  'OMIM:156810',
#  'OMIM:156830',
#  'OMIM:156850',
#  'OMIM:156900',
#  'OMIM:157150',
#  'OMIM:157170',
#  'OMIM:157300',
#  'OMIM:157400',
#  'OMIM:157600',
#  'OMIM:157640',
#  'OMIM:157700',
#  'OMIM:157800',
#  'OMIM:157900',
#  'OMIM:157950',
#  'OMIM:157980',
#  'OMIM:158000',
#  'OMIM:158100',
#  'OMIM:158170',
#  'OMIM:158250',
#  'OMIM:158280',
#  'OMIM:158300',
#  'OMIM:158310',
#  'OMIM:158320',
#  'OMIM:158330',
#  'OMIM:158345',
#  'OMIM:158350',
#  'OMIM:158400',
#  'OMIM:158500',
#  'OMIM:158580',
#  'OMIM:158590',
#  'OMIM:158600',
#  'OMIM:158650',
#  'OMIM:158800',
#  'OMIM:158810',
#  'OMIM:158900',
#  'OMIM:158901',
#  'OMIM:159050',
#  'OMIM:159400',
#  'OMIM:159500',
#  'OMIM:159550',
#  'OMIM:159580',
#  'OMIM:159595',
#  'OMIM:159600',
#  'OMIM:159800',
#  'OMIM:159900',
#  'OMIM:159950',
#  'OMIM:160010',
#  'OMIM:160120',
#  'OMIM:160150',
#  'OMIM:160300',
#  'OMIM:160500',
#  'OMIM:160565',
#  'OMIM:160570',
#  'OMIM:160700',
#  'OMIM:160750',
#  'OMIM:160800',
#  'OMIM:160900',
#  'OMIM:160980',
#  'OMIM:161000',
#  'OMIM:161050',
#  'OMIM:161200',
#  'OMIM:161400',
#  'OMIM:161470',
#  'OMIM:161480',
#  'OMIM:161500',
#  'OMIM:161530',
#  'OMIM:161550',
#  'OMIM:161700',
#  'OMIM:161800',
#  'OMIM:161900',
#  'OMIM:161950',
#  'OMIM:162000',
#  'OMIM:162091',
#  'OMIM:162100',
#  'OMIM:162200',
#  'OMIM:162210',
#  'OMIM:162240',
#  'OMIM:162260',
#  'OMIM:162300',
#  'OMIM:162350',
#  'OMIM:162370',
#  'OMIM:162400',
#  'OMIM:162500',
#  ...]

# %%
from counting_proporion_enrichment_of_hpo_and_nanatmaj  import count_vpk_proportions

# %%
# vpk_label_df, disease_df, disease_hpo_dict, disease_name_dict
disease_nanatmaj_and_vpk_count_df, success_count, empty_disease_list = count_vpk_proportions(frozen_consensus_master_sheet_nanatmaj_with_hpo, disease_list, disease_hpo_dict, disease_name_dict)
disease_nanatmaj_and_vpk_count_df
# Out:
#          disease_id                                       disease_name  \
# 0        DECIPHER:1                         [Wolf-Hirschhorn syndrome]
# 1       DECIPHER:14                   [Prader-Willi syndrome (Type 1)]
# 2       DECIPHER:15                       [Nf1-Microdeletion syndrome]
# 3       DECIPHER:16  [22q11 deletion syndrome (Velocardiofacial / D...
# 4       DECIPHER:17                                   [Sotos syndrome]
# ...             ...                                                ...
# 12733   ORPHA:88616  [Autosomal recessive non-syndromic intellectua...
# 12734    ORPHA:3135                     [Familial Scheuermann disease]
# 12735     ORPHA:777   [X-linked non-syndromic intellectual disability]
# 12736   ORPHA:86914  [Lymphedema-cerebral arteriovenous anomaly syn...
# 12737  ORPHA:528084   [Non-specific syndromic intellectual disability]
#
#        v_count  p_count  k_count  nv_count  np_count  nk_count
# 0            4        1        0         1         0         0
# 1            3        1        1         0         0         1
# 2            5        2        0         0         0         0
# 3            5        1        1         0         0         0
# 4            4        1        0         0         0         0
# ...        ...      ...      ...       ...       ...       ...
# 12733       36        6        3         2         0         0
# 12734        2        0        0         0         0         0
# 12735       34        5        4         2         0         1
# 12736        1        1        1         0         0         0
# 12737       68        6        5         3         0         0
#
# [12738 rows x 8 columns]

# %%
empty_disease_list
# Out:
# []

# %%
hpo_disease_dict['HP:0004495']
# Out:
# ['OMIM:164200', 'ORPHA:2710', 'ORPHA:2306']

# %%
disease_nanatmaj_and_vpk_count_df.to_excel('disease_nanatmaj_and_vpk_count_V_160923.xlsx')
