# %%
import numpy as np 
import pandas as pd 
import pickle
from collections import defaultdict

# %%
def pickle_load(file_path):
    """
    Loads a pickled object from the specified file path.
    """
    with open(file_path, 'rb') as handle:
        b = pickle.load(handle)
    return b

    # defining dictonary path 
path_disease_hpo_dict = 'D:\learning\HPOA dataset\GitHub uploads\Final_concnecous\data_retrival\disease_hpo_dict_V_110923.pickle'
path_disease_name_dict = 'D:\learning\HPOA dataset\GitHub uploads\Final_concnecous\data_retrival\disease_name_dict_V_110923.pickle'
path_hpid_descriptions_dict = 'D:\learning\HPOA dataset\GitHub uploads\Final_concnecous\data_retrival\hpid_descriptions_dict_V_110923.pickle'
path_hpid_vpk_label_dict = 'D:\learning\HPOA dataset\GitHub uploads\Final_concnecous\data_retrival\hpid_vpk_label_dict_V_110923.pickle'
path_hpo_disease_dict = 'D:\learning\HPOA dataset\GitHub uploads\Final_concnecous\data_retrival\hpo_disease_dict_V_110923.pickle'
path_disease_vpk_count_dict = 'D:\learning\HPOA dataset\GitHub uploads\Final_concnecous\data_retrival\disease_vpk_count_dict_V_110923.pickle'


# loading dicts #tanay path
disease_hpo_dict = pickle_load(path_disease_hpo_dict)
disease_name_dict =  pickle_load(path_disease_name_dict)
hpid_descriptions_dict =  pickle_load(path_hpid_descriptions_dict)
hpid_vpk_label_dict =  pickle_load(path_hpid_vpk_label_dict)
hpo_disease_dict =  pickle_load(path_hpo_disease_dict)
disease_vpk_count_dict = pickle_load(path_disease_vpk_count_dict)

# %%
combined_nanatmaj_phenotypes_df = pd.read_excel('D:\learning\HPOA dataset\GitHub uploads\Final_concnecous\data_retrival\Combined_nanatmaj_phenotypes.xlsx')
combined_nanatmaj_phenotypes_df = combined_nanatmaj_phenotypes_df.drop_duplicates()
combined_nanatmaj_phenotypes_df = combined_nanatmaj_phenotypes_df.reset_index().drop(['index'], axis =1)
combined_nanatmaj_phenotypes_df
# Out:
#     Phenotype_ID
# 0     HP:0000964
# 1     HP:0003765
# 2     HP:0010280
# 3     HP:0030318
# 4     HP:0011830
# ..           ...
# 222   HP:0000045
# 223   HP:0100813
# 224   HP:0000036
# 225   HP:0032150
# 226   HP:0500005
#
# [227 rows x 1 columns]

# %%
# nanatmaj_hpid_freq_dict = defaultdict(int)
# type(nanatmaj_hpid_freq_dict)

# %%
def calculte_hpid_freq(phenotype_df, hpo_disease_dict):
    """
    Calculate the frequency of each HPO term in a phenotype.
    """

    retrun_frequecy_dict = defaultdict(int)

    for i in range(len(phenotype_df)):
        # print(i)
        # print(phenotype_df.iloc[i, 0])
        temp_frequency = len(hpo_disease_dict[phenotype_df.iloc[i, 0]])
        # if ()
        retrun_frequecy_dict[phenotype_df.iloc[i, 0]] = temp_frequency

    return retrun_frequecy_dict

# %%
nanatmaj_hpid_freq_dict = calculte_hpid_freq(combined_nanatmaj_phenotypes_df, hpo_disease_dict)
nanatmaj_hpid_freq_df = pd.DataFrame.from_dict(nanatmaj_hpid_freq_dict, orient= 'index')
nanatmaj_hpid_freq_df.columns = ['Phenotype_ID', 'Frequency']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\learning\HPOA dataset\GitHub uploads\Final_concnecous\Clustering_Nanatmaj\frequency_calculation_and_Bubble_plot.ipynb Cell 6 line <cell line: 3>()
#       <a href='vscode-notebook-cell:/d%3A/learning/HPOA%20dataset/GitHub%20uploads/Final_concnecous/Clustering_Nanatmaj/frequency_calculation_and_Bubble_plot.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> nanatmaj_hpid_freq_dict = calculte_hpid_freq(combined_nanatmaj_phenotypes_df, hpo_disease_dict)
#       <a href='vscode-notebook-cell:/d%3A/learning/HPOA%20dataset/GitHub%20uploads/Final_concnecous/Clustering_Nanatmaj/frequency_calculation_and_Bubble_plot.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> nanatmaj_hpid_freq_df = pd.DataFrame.from_dict(nanatmaj_hpid_freq_dict, orient= 'index')
# ----> <a href='vscode-notebook-cell:/d%3A/learning/HPOA%20dataset/GitHub%20uploads/Final_concnecous/Clustering_Nanatmaj/frequency_calculation_and_Bubble_plot.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> nanatmaj_hpid_freq_df.columns = ['Phenotype_ID', 'Frequency']
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:5596, in NDFrame.__setattr__(self, name, value)
#    5594 try:
#    5595     object.__getattribute__(self, name)
# -> 5596     return object.__setattr__(self, name, value)
#    5597 except AttributeError:
#    5598     pass
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\properties.pyx:70, in pandas._libs.properties.AxisProperty.__set__()
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:769, in NDFrame._set_axis(self, axis, labels)
#     767 def _set_axis(self, axis: int, labels: Index) -> None:
#     768     labels = ensure_index(labels)
# --> 769     self._mgr.set_axis(axis, labels)
#     770     self._clear_item_cache()
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\internals\managers.py:214, in BaseBlockManager.set_axis(self, axis, new_labels)
#     212 def set_axis(self, axis: int, new_labels: Index) -> None:
#     213     # Caller is responsible for ensuring we have an Index object.
# --> 214     self._validate_set_axis(axis, new_labels)
#     215     self.axes[axis] = new_labels
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\internals\base.py:69, in DataManager._validate_set_axis(self, axis, new_labels)
#      66     pass
#      68 elif new_len != old_len:
# ---> 69     raise ValueError(
#      70         f"Length mismatch: Expected axis has {old_len} elements, new "
#      71         f"values have {new_len} elements"
#      72     )
#
# ValueError: Length mismatch: Expected axis has 1 elements, new values have 2 elements

# %%
# Out:
# ['HP:0000348',
#  'HP:0000365',
#  'HP:0000400',
#  'HP:0000405',
#  'HP:0000431',
#  'HP:0000483',
#  'HP:0000486',
#  'HP:0000494',
#  'HP:0000505',
#  'HP:0000508',
#  'HP:0000581',
#  'HP:0000826',
#  'HP:0000957',
#  'HP:0001085',
#  'HP:0001105',
#  'HP:0001212',
#  'HP:0001250',
#  'HP:0001252',
#  'HP:0001273',
#  'HP:0001382',
#  'HP:0001385',
#  'HP:0001519',
#  'HP:0001611',
#  'HP:0001761',
#  'HP:0002236',
#  'HP:0002360',
#  'HP:0002381',
#  'HP:0002553',
#  'HP:0002616',
#  'HP:0002650',
#  'HP:0002808',
#  'HP:0004325',
#  'HP:0004482',
#  'HP:0004927',
#  'HP:0005280',
#  'HP:0006913',
#  'HP:0006934',
#  'HP:0007018',
#  'HP:0009921',
#  'HP:0010055',
#  'HP:0010109',
#  'HP:0011081',
#  'HP:0011098',
#  'HP:0011220',
#  'HP:0011304',
#  'HP:0011344',
#  'HP:0011968',
#  'HP:0025269',
#  'HP:0030084',
#  'HP:0000046',
#  'HP:0031629',
#  'HP:0040018',
#  'HP:0200021',
#  'HP:0001249',
#  'HP:0000750',
#  'HP:0001263',
#  'HP:0000729',
#  'HP:0001256',
#  'HP:0001999',
#  'HP:0002194',
#  'HP:0010863',
#  'HP:0000028',
#  'HP:0000160',
#  'HP:0000218',
#  'HP:0000233',
#  'HP:0000252',
#  'HP:0000275',
#  'HP:0000276',
#  'HP:0000316',
#  'HP:0000319',
#  'HP:0000343',
#  'HP:0000347']
