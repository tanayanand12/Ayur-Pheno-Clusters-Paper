# %%
import pickle
import pandas as pd 
import numpy as np

# %%
def pickle_load(file_path):
    with open(file_path, 'rb') as handle:
        b = pickle.load(handle)
    return b

# %%
# loading dicts #tanay path
disease_hpo_dict = pickle_load('disease_hpo_dict_V_110923.pickle')
disease_name_dict =  pickle_load('disease_name_dict_V_110923.pickle')
hpid_descriptions_dict =  pickle_load('hpid_descriptions_dict_V_110923.pickle')
hpid_vpk_label_dict =  pickle_load('hpid_vpk_label_dict_V_110923.pickle')
hpo_disease_dict =  pickle_load('hpo_disease_dict_V_110923.pickle')
disease_vpk_count_dict = pickle_load('disease_vpk_count_dict_V_110923.pickle')

# %%
path_disease_hpo_dict = 'D:\learning\HPOA dataset\GitHub uploads\Final_concnecous\data_retrival\disease_hpo_dict_V_110923.pickle'
path_disease_name_dict = 'D:\learning\HPOA dataset\GitHub uploads\Final_concnecous\data_retrival\disease_name_dict_V_110923.pickle'
path_hpid_descriptions_dict = 'D:\learning\HPOA dataset\GitHub uploads\Final_concnecous\data_retrival\hpid_descriptions_dict_V_110923.pickle'
path_hpid_vpk_label_dict = 'D:\learning\HPOA dataset\GitHub uploads\Final_concnecous\data_retrival\hpid_vpk_label_dict_V_110923.pickle'
path_hpo_disease_dict = 'D:\learning\HPOA dataset\GitHub uploads\Final_concnecous\data_retrival\hpo_disease_dict_V_110923.pickle'
path_disease_vpk_count_dict = 'D:\learning\HPOA dataset\GitHub uploads\Final_concnecous\data_retrival\disease_vpk_count_dict_V_110923.pickle'

# %%
vata_phenotypes_df = pd.read_excel(r'Vata_phenotypes.xlsx')
vata_phenotypes_df.drop_duplicates()
# Out:
#     Phenotype_ID
# 0     HP:0000496
# 1     HP:0012228
# 2     HP:0025264
# 3     HP:0000217
# 4     HP:0000360
# ..           ...
# 151   HP:0000045
# 152   HP:0100813
# 153   HP:0000036
# 155   HP:0032150
# 156   HP:0500005
#
# [151 rows x 1 columns]

# %%
vata_phenotypes_df_list = vata_phenotypes_df.values.tolist()
vata_phenotypes_df_list = [i for row in vata_phenotypes_df_list for i in row]

# %%
main_disease_list_vata = []
res_hpid_column_list = []
suspicious_pid_list = []

# count = 0
for p_id in vata_phenotypes_df['Phenotype_ID']:
    temp_disease_list  = hpo_disease_dict[p_id]
    if (temp_disease_list == []):
        suspicious_pid_list.append(p_id)
    # temp_hpid_list = np.full((len(temp_disease_list)), p_id)
    temp_hpid_list = []
    given_value= p_id
    temp_hpid_list.extend([given_value for i in range(len(temp_disease_list))])
    # print('len of disease list: ', len(temp_disease_list))
    # print("length of temp: ",len(temp_hpid_list))
    main_disease_list_vata.append(temp_disease_list)
    res_hpid_column_list.append(temp_hpid_list)
    # print('length of res: ',len(res_hpid_column_list), "\n\n\n")
    # print(res_hpid_column_list)
    # if (count == 10):
    #     break
    
    # count += 1

temp_disease_list.clear()
temp_hpid_list.clear()

main_disease_list_vata = [i for row in main_disease_list_vata for i in row]
res_hpid_column_list = [i for row in res_hpid_column_list for i in row]
# main_disease_list_vata = np.unique(main_disease_list_vata)
len(main_disease_list_vata)
# Out:
# 11825

# %%
suspicious_pid_list
# Out:
# ['HP:0012228',
#  'HP:0031685',
#  'HP:0034782',
#  'HP:0011006',
#  'HP:0001441',
#  'HP:0008542',
#  'HP:0030956',
#  'HP:0033129',
#  'HP:0034808',
#  'HP:0032000',
#  'HP:0034788',
#  'HP:0033771',
#  'HP:0034267',
#  'HP:0034518',
#  'HP:0041051',
#  'HP:0032150']

# %%
len(res_hpid_column_list)
# Out:
# 11825

# %%
disease_name_list = []
for disease_id in main_disease_list_vata:
    disease_name_list.append(disease_name_dict[disease_id])

len(disease_name_list)
# Out:
# 11825

# %%
print(res_hpid_column_list)
# Out:
# ['HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP:0000496', 'HP
# ...

# %%
np_res_hpid_column_list = np.unique(res_hpid_column_list)
len(np_res_hpid_column_list)
# Out:
# 134

# %%
# MBA_vata_phenotypes = pd.DataFrame(np_res_hpid_column_list, columns=['Phenotype_ID'])
# MBA_vata_phenotypes.to_csv('MBA_vata_phenotypes')

# %%
return_df_vata = pd.DataFrame(columns=['Disease_ID', 'Disease_Name', 'HP_ID'])

return_df_vata['Disease_ID'] = main_disease_list_vata
return_df_vata['Disease_Name'] = disease_name_list
return_df_vata['HP_ID'] = res_hpid_column_list

# %%
return_df_vata
# Out:
#          Disease_ID                                       Disease_Name  \
# 0       OMIM:618076  [Neurodevelopmental disorder with spasticity a...
# 1       OMIM:618249  [Mitochondrial complex I deficiency, nuclear t...
# 2       OMIM:618088  [Neurodevelopmental disorder with regression, ...
# 3       OMIM:617622                              [Joubert syndrome 30]
# 4       OMIM:300966       [Mental retardation, X-linked, syndromic 33]
# ...             ...                                                ...
# 11820   ORPHA:71211           [Neuromyelitis optica spectrum disorder]
# 11821   ORPHA:94058                             [Neovascular glaucoma]
# 11822  ORPHA:293381           [Epithelial recurrent erosion dystrophy]
# 11823  ORPHA:280914                      [Idiopathic anterior uveitis]
# 11824  ORPHA:280921                            [Idiopathic panuveitis]
#
#             HP_ID
# 0      HP:0000496
# 1      HP:0000496
# 2      HP:0000496
# 3      HP:0000496
# ...

# %%
# return_df_vata.to_excel('Pitta_disease_with_names.xlsx')

# %%
empty_list_phenotype = []
for key in hpo_disease_dict:
    if(hpo_disease_dict[key] == []):
        empty_list_phenotype.append(key)


len(empty_list_phenotype)
# Out:
# 17

# %%
empty_list_phenotype
# Out:
# ['HP:0500005',
#  'HP:0012228',
#  'HP:0031685',
#  'HP:0034782',
#  'HP:0011006',
#  'HP:0001441',
#  'HP:0008542',
#  'HP:0030956',
#  'HP:0033129',
#  'HP:0034808',
#  'HP:0032000',
#  'HP:0034788',
#  'HP:0033771',
#  'HP:0034267',
#  'HP:0034518',
#  'HP:0041051',
#  'HP:0032150']

# %%
# hpo_disease_dict['HP:0500005'] = ['OMIM:167400', 'ORPHA:209964', 'ORPHA:65250']
# hpo_disease_dict['HP:0500005']

# %%
def pickle_save(file_name, dict_name):
    with open(file_name, 'wb') as handle:
        pickle.dump(dict_name, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# pickle_save('hpo_disease_dict_V_110923.pickle', hpo_disease_dict)

# %%
# disease_hpo_dict['OMIM:0012228']

# %%
# test_dict = pickle_load('D:\learning\HPOA dataset\GitHub uploads\Final_concnecous\data_retrival\hpo_disease_dict_V_110923.pickle')
# test_dict['HP:0500005']

# %%
from disease_retrival_from_phenotype_and_vice_versa import retrive_diseases

# %%
# pitta_phenotypes_df = pd.read_excel(r'Pitta_phenotypes.xlsx')
# pitta_phenotypes_df

# %%
# retrived_pitta_diseases = retrive_diseases(pitta_phenotypes_df)

# %%
# retrived_pitta_diseases.to_excel('Pitta_diseases_with_names.xlsx')

# %%
kapha_phenotypes_df = pd.read_excel('D:\learning\HPOA dataset\GitHub uploads\Final_concnecous\data_retrival\Kappha_phenotypes.xlsx')
# kapha_phenotype_df

# %%
retrived_kapha_diseases = retrive_diseases(kapha_phenotypes_df)
# retrived_kapha_diseases

# %%
# retrived_kapha_diseases.to_excel('Kapha_diseases_with_names.xlsx')

# %%
disease_name_dict['ORPHA:280921'][0]
# Out:
# 'Idiopathic panuveitis'
